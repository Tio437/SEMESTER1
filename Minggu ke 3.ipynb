# %%
print('Python is powerful')
# Out:
# Python is powerful

# %%
print('Good Morning!')
print('It is rainy today')
# Out:
# Good Morning!
# It is rainy today

# %%
# print with end whitespace
#print('Good Morning!', end= ' ')

print('Good Morning!', end = ' ')

print('It is rainy today')
# Out:
# Good Morning! It is rainy today

# %%
print('New Year', 2023, 'See you soon!', sep= '. ')
# Out:
# New Year. 2023. See you soon!

# %%
number = -10.6

name = "Teknologi Informasi"

# print literals
print(5)

# print variables
print(number)
print(name)
# Out:
# 5
# -10.6
# Teknologi Informasi

# %% [markdown]
# Print Concatenated Strings

# %%
print('Teknologi Informasi ' + 'Universitas Tidar')
# Out:
# Teknologi Informasi Universitas Tidar

# %% [markdown]
# output formatting

# %%
x = 5
y = 10

print('The value of x is {} and y is {}'.format(x,y))
# Out:
# The value of x is 5 and y is 10

# %% [markdown]
# baasic input in python

# %% [markdown]
# python user input

# %% [markdown]
# download data

# %%
# Download Example file
# !mkdir -p /resources/data
# !wget -O /resources/data/Example1.txt https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/labs/example1.txt
# Out:
# --2024-09-06 06:22:53--  https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/labs/example1.txt
# Resolving s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)... 67.228.254.196
# Connecting to s3-api.us-geo.objectstorage.softlayer.net (s3-api.us-geo.objectstorage.softlayer.net)|67.228.254.196|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘/resources/data/Example1.txt’
#
# /resources/data/Exa 100%[===================>]      45  --.-KB/s    in 0s
#
# 2024-09-06 06:22:53 (13.3 MB/s) - ‘/resources/data/Example1.txt’ saved [45/45]

# %%
# Read the Example1.txt

example1 = "/resources/data/Example1.txt"
file1 = open(example1, "r")

# %%
file1.name
# Out:
# '/resources/data/Example1.txt'

# %%
# Print the mode of file, either 'r' or 'w'

file1.mode
# Out:
# 'r'

# %%
# Open file using with

with open(example1, "r") as file1:
    FileContent = file1.read()
    print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %% [markdown]
# CARA AGAK LAEN TUGAS 1 TAPI GAGAL YANG BENER DI BAWAH NYA
#
# 1.   Item daftar
# 2.   Item daftar

# %%
nama = input('NAMA: ')
npm = input('NPM: ')
alamat = input('ALAMAT:')
prodi = input('PROGRAM STUDI: ')
hoby = input('HOBY: ')
email = input('EMAIL: ')


biodata = "NAMA : {}\nPROGRAM STUDI : {} \nNPM : {}\nALAMAT : {}\nHOBY : {}\nEMAIL : {}".format(nama, npm, alamat, prodi, hoby,email)

print(biodata)

with open('biodata.txt', 'w') as writefile:
    writefile.write(biodata)
# Out:
# NAMA: e
# NPM:
# ALAMAT:e
# PROGRAM STUDI: e
# HOBY: e
# EMAIL: e
# NAMA : e
# PROGRAM STUDI :
# NPM : e
# ALAMAT : e
# HOBY : e
# EMAIL : e

# %% [markdown]
# WELKYY EXERCISE 1

# %%
with open('BioTio.txt', 'w') as writefile:
    writefile.write("Nama   : Tio Restu Pambudi\n")
    writefile.write("Prodi  : S1 Teknologi Informasi\n")
    writefile.write("NPM    : 2440506076\n")
    writefile.write("Alamat : Magelang \n")
    writefile.write("hobi   : Tidur\n")
    writefile.write("email  : pambuditio437@gmail.com")

# %%
with open("BioTio.txt","r") as tio :
  t = tio.readlines()
  print(t[0])
  print(t[1])
  print(t[5])
# Out:
# Nama   : Tio Restu Pambudi
#
# Prodi  : S1 Teknologi Informasi
#
# email  : pambuditio437@gmail.com

# %%
with open("BioTio.txt","r") as readfile :
      with open('BioTio2.txt','w') as writefile:
                writefile.write(t[0])
                writefile.write(t[2])
                writefile.write(t[1])
                writefile.write(t[3])

# %% [markdown]
# WELKYY EXERCISE 2

# %%
print ("Selamat datang di Toko Maju Jaya")
print ("Senin, 4 September 2023       13.05")
print(" ")

print ("DAFTAR BELANJA:")
item1 = "Sabun"
item2 = 'Shampo'
item3 = "Mie instant"
item4 = "Detergen"
harga1 = 10000
harga2 = 15000
harga3 = 5000
harga4 = 17500

total = harga1+harga2+harga3+harga4

print(item1, " = Rp ",harga1)
print(item2, " = Rp ",harga2)
print(item3, " = Rp ",harga3)
print(item4, " = Rp ",harga4)

print(" ")
print("Total = Rp ",total)

with open('KuitansiTio.txt','w') as writefile:
        writefile.write("Selamat Datang di Toko Maju Jaya\n")
        writefile.write("Kuitansi - 4 Septermber 2023\n")
        writefile.write(" \n")
        writefile.write(item1 +" = Rp " + str(harga1) + "\n")
        writefile.write(item2 +" = Rp " + str(harga2) + "\n")
        writefile.write(item3 +" = Rp " + str(harga3) + "\n")
        writefile.write(item4 +" = Rp " + str(harga4) + "\n")
        writefile.write(" \n")
        writefile.write("Total Belanja ="+ str (total))
# Out:
# Selamat datang di Toko Maju Jaya
# Senin, 4 September 2023       13.05
#
# DAFTAR BELANJA:
# Sabun  = Rp  10000
# Shampo  = Rp  15000
# Mie instant  = Rp  5000
# Detergen  = Rp  17500
#
# Total = Rp  47500
