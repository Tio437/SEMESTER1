# %%
intput = int(input("masukan angka : "))

def faktorial(n):
    if n == 0:
        return 1
    else:
        return n * faktorial(n-1)

print(f"faktorial dari {intput} adalah {faktorial(intput)}")
# Out:
# masukan angka : 5
# faktorial dari 5 adalah 120

# %%
def luas_persegi(sisi):
    return sisi * sisi

def luas_segitiga(alas, tinggi):
    return 0.5 * alas * tinggi

def luas_lingkaran(jari_jari):
    return 3.14 * jari_jari * jari_jari

def pilih ():
  while True:
    print("Pilih bentuk yang ingin dihitung luasnya:")
    print("1. Persegi")
    print("2. Segitiga")
    print("3. Lingkaran")
    print("4. selesai")
    pilihan = int(input("Masukkan nomor pilihan Anda: "))
    if pilihan == 1:
      sisi = float(input("Masukkan panjang sisi persegi: "))
      luas = luas_persegi(sisi)
      print(f"Luas persegi dengan sisi {sisi} adalah {luas}")
    elif pilihan == 2:
      alas = float(input("Masukkan panjang alas segitiga: "))
      tinggi = float(input("Masukkan tinggi segitiga: "))
      luas = luas_segitiga(alas, tinggi)
      print(f"Luas segitiga dengan alas {alas} dan tinggi {tinggi} adalah {luas}")
    elif pilihan == 3:
      jari_jari = float(input("Masukkan jari-jari lingkaran: "))
      luas = luas_lingkaran(jari_jari)
      print(f"Luas lingkaran dengan jari-jari {jari_jari} adalah {luas}")
    elif pilihan == 4:
      print("Terima kasih! Program selesai.")
      break
    else:
      print("Pilihan tidak ada. Silakan coba lagi.")
pilih()
# Out:
# Pilih bentuk yang ingin dihitung luasnya:
# 1. Persegi
# 2. Segitiga
# 3. Lingkaran
# 4. selesai
# Masukkan nomor pilihan Anda: 2
# Masukkan panjang alas segitiga: 3
# Masukkan tinggi segitiga: 4
# Luas segitiga dengan alas 3.0 dan tinggi 4.0 adalah 6.0
# Pilih bentuk yang ingin dihitung luasnya:
# 1. Persegi
# 2. Segitiga
# 3. Lingkaran
# 4. selesai
# Masukkan nomor pilihan Anda: 3
# Masukkan jari-jari lingkaran: 4
# Luas lingkaran dengan jari-jari 4.0 adalah 50.24
# Pilih bentuk yang ingin dihitung luasnya:
# 1. Persegi
# 2. Segitiga
# 3. Lingkaran
# 4. selesai
# Masukkan nomor pilihan Anda: 4
# Terima kasih! Program selesai.
